# %% [markdown]
# ### Smaller datasets found in the collection

# %%
import pandas as pd

# %% [markdown]
# ### dos_database table inside recalbox_gamelist.mdb

# %%
dos_database = pd.read_excel('dos_database.xlsx')

# %%
dos_database
# Out:
#                gametitle_mame        developer_mame        year_mame  \
# 0     ...A Personal Nightmare      Horror Soft Ltd.  19890101T000000
# 1                   .386 Spys        Genki Software  19890101T000000
# 2             ¿Quien es Cualo         BASS Software  19940101T000000
# 3                          +K           Luis Crespo  19960101T000000
# 4                  µLabyrinth            Gamos Ltd.  19930101T000000
# ...                       ...                   ...              ...
# 7477                  Zyconix         Miracle Games  19920101T000000
# 7478                     Zyll                   IBM  19840101T000000
# 7479                      ZZT  Epic MegaGames, Inc.  19910101T000000
# 7480               ZZT's City   Softdisk Publishing  19910101T000000
# 7481           ZZT's Revenge!  Epic MegaGames, Inc.  19920101T000000
#
#                                              genre_mame  \
# 0                                             Adventure
# ...

# %% [markdown]
# ### gamelist_xml table inside recalbox_gamelist.mdb

# %%
gamelist = pd.read_excel('gamelist.xlsx')

# %%
gamelist
# Out:
#                                              nomjeu_rom  \
# 0                                      16 Zhang Mahjong
# 1                                     16BIT Rhythm Land
# 2                                    3 Ninjas Kick Back
# 3     Golf Magazine presents 36 Great Holes starring...
# 4                                        688 Attack Sub
# ...                                                 ...
# 1037                                            Zombies
# 1038                                            Zombies
# 1039                Zool : Ninja of the 'Nth' Dimension
# 1040                                              Zoom!
# 1041                                               Zoop
#
#                                             fichier_rom  \
# 0                      ./16 Tiles Mahjong (Unl) [c].bin
# 1                              ./16-Bit Rhythm Land.bin
# 2                      ./3 Ninjas Kick Back (U) [!].bin
# 3     ./36 Great Holes Starring Fred Couples 32X (E)...
# ...
